# %% [markdown]
# <a href="https://colab.research.google.com/github/jaesgithub/ECON-323/blob/main/January_29th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# 1D Array
x = np.array([1, 2, 3, 4])
print(x.shape) # 4 elements, 1 dimension
print(x.dtype)
# Out:
# (4,)
# int64

# %%
x = np.array([True, False, True])
print(x.shape)
print(x.dtype)
# Out:
# (3,)
# bool

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])
print(x.shape) # 2 rows and 3 columns
print(x.dtype)
# Out:
# (2, 3)
# int64

# %%
rows, columns = x.shape
