# %%
x = "something else"

# %%
print(x)
# Out:
# something else

# %%
x.split()
# Out:
# ['something', 'else']

# %%
type(3)
# Out:
# int

# %%
type("hello")
# Out:
# str

# %%
type(3.78)
# Out:
# float

# %%
li = [1, 2, 3]

# %%
type(li)
# Out:
# list

# %%
tu = (1, 2, 3)

# %%
type(tu)
# Out:
# tuple

# %% [markdown]
# ### Accessing elements
# You can access individual elements of a tuple using indexing (starting from 0) or a range of elements using slicing.

# %%
print(f"Original tuple: {tu}")

# Accessing an element by index
print(f"First element: {tu[0]}")

# Slicing the tuple
print(f"Elements from index 1 to the end: {tu[1:]}")

# %% [markdown]
# ### Concatenation
# You can combine two or more tuples using the `+` operator.

# %%
tuple_new = tu + (4, 5, 6)
print(f"Concatenated tuple: {tuple_new}")

# %% [markdown]
# ### Repetition
# You can repeat a tuple using the `*` operator.

# %%
repeated_tuple = tu * 2
print(f"Repeated tuple: {repeated_tuple}")

# %% [markdown]
# ### Membership testing
# You can check if an element exists in a tuple using the `in` operator.

# %%
print(f"Is 2 in tu? {2 in tu}")
print(f"Is 5 in tu? {5 in tu}")

# %% [markdown]
# ### Tuple length
# You can find the number of elements in a tuple using the `len()` function.

# %%
print(f"Length of tu: {len(tu)}")

# %%
di = {"name" : "John", "age": 20}

# %%
type(di)
# Out:
# dict

# %%
import pandas as pd

# %%
import numpy as np

# %%
x = 1_345.25 # _ replaces , for readability

# %%
x
# Out:
# 1345.25

# %%
x = 1345.25

# %%
x
# Out:
# 1345.25

# %%
a = 4
b = 2
print("a+b is", a+b)
# Out:
# a+b is 6

# %%
print(a+b)
# Out:
# 6

# %%
print("a*b = ", a*b)
# Out:
# a*b =  8

# %%
print("a divided by b is", a/b)
# Out:
# a divided by b is 2.0

# %%
print(a**b)
# Out:
# 16

# %%
a = 4
b = 2.0

# %%
a+b
# Out:
# 6.0

# %%
x = 2.0
y = 3.0
z1 = x+y*x
z1
# Out:
# 8.0

# %%
(x+y)*y
# Out:
# 15.0

# %%
import math

# %%
math.sin(2.5)
# Out:
# 0.5984721441039565

# %%
math.pi
# Out:
# 3.141592653589793

# %%
5//2
# Out:
# 2

# %%
13//3 # Closest whole number
# Out:
# 4

# %%
13%3 # Remainder
# Out:
# 1

# %%
x = "hello"
y = "world"

# %%
x+y
# Out:
# 'helloworld'

# %%
3*x
# Out:
# 'hellohellohello'

# %%
a = "2"
b = 3
a*b
# Out:
# '222'

# %%
x = "HELLO"

# %%
x.lower() # Changes string to lower cases
# Out:
# 'hello'

# %%
x.upper() # Changes string to upper cases
# Out:
# 'HELLO'

# %%
x.count("H") # Counts how many H there are in x, case sensitive
# Out:
# 1

# %%
x.count("L")
# Out:
# 2

# %%
country = "Canada"
GDP = 3.0
year = 2024

f"{country} had GDP ${GDP} trillions in {year}"
# Out:
# 'Canada had GDP $3.0 trillions in 2024'

# %%
f"{5}**2 = {5**2}"
# Out:
# '5**2 = 25'

# %%
x = True
y = False

# %%
type(x)
# Out:
# bool

# %%
a = 4
b = 2

# %%
a > b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False
