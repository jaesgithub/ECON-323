# %%
lst = [2.0, 91.1, 12.5]

# %%
type(lst)
# Out:
# list

# %%
2.0 in lst
# Out:
# True

# %%
4 in lst
# Out:
# False

# %%
lst.reverse()
lst
# Out:
# [2.0, 91.1, 12.5]

# %%
x = [2.0, 91.1, 12.5]

# %%
x.reverse()
print(x)
# Out:
# [2.0, 91.1, 12.5]

# %%
str_list = ["NY", "AZ", "TX"]

# %%
str_list.sort()
print(str_list)
# Out:
# ['AZ', 'NY', 'TX']

# %%
num_list = [10, 25, 42, 8]

# %%
num_list.append(100)
print(num_list)
# Out:
# [10, 25, 42, 8, 100]

# %%
num_list.append([20, 5])
print(num_list)
# Out:
# [10, 25, 42, 8, 100, [20, 5]]

# %%
x = [2, 9.1, 12.5]

# %%
import numpy as np

# %%
np.mean(x)
# Out:
# np.float64(2.5)

# %% [markdown]
# This will explicitly cast the `numpy.float64` object to a standard Python `float`, and then printing it will display only the numerical value.

# %%
result = np.mean(x)
print(float(result))
# Out:
# 2.5

# %%
x = [2, "hello", 3.0]

# %%
type(x[1])
# Out:
# str

# %%
type(x[2])
# Out:
# float

# %%
type([3])
# Out:
# list

# %%
range(5) # Ouputs 0 to 4
# Out:
# range(0, 5)

# %%
print(range(5))
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
range(2, 5)
# Out:
# range(2, 5)

# %%
list(range(2, 5))
# Out:
# [2, 3, 4]

# %%
list(range(2, 10, 2))
# Out:
# [2, 4, 6, 8]

# %%
t = (1, "hello", 3.0)

# %%
t
# Out:
# (1, 'hello', 3.0)

# %%
list(t)
# Out:
# [1, 'hello', 3.0]

# %%
t[1]
# Out:
# 'hello'

# %%
x, y = (1, "test")

# %%
print(f"1 = {x}, 2 = {y}")
# Out:
# 1 = 1, 2 = test

# %%
print(f"A = {x}, B = {y}")
# Out:
# A = 1, B = test

# %%
china_data_2025 = ("China", 2015, 11.06, 1.371)
print(china_data_2025)
# Out:
# ('China', 2015, 11.06, 1.371)

# %%
china_data = [(2015, 11.06, 1.371), (2014, 10.48, 1.364), (2013, 9.607, 1.357)]

# %%
gdp_data = [9.607, 10.48, 11.06]
years = [2013, 2014, 2015]

# %%
zip(years, gdp_data)

# %%
print(zip(years, gdp_data))

# %%
list(zip(years, gdp_data))
# Out:
# [(2013, 9.607), (2014, 10.48), (2015, 11.06)]

# %%
l = list(zip(years, gdp_data))
x, y = l[0]

# %%
print(f"year = {x}, GDP = {y}")
# Out:
# year = 2013, GDP = 9.607

# %%
e = enumerate(["a", "b", "c"])

# %%
e

# %%
list(e)
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
print(e)
