# %% [markdown]
# <a href="https://colab.research.google.com/github/jaesgithub/ECON-323/blob/main/February_3rd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as web
import datetime as dt

# %%
fig, ax = plt.subplots()

x = np.linspace(0, 2*np.pi, 100) # 100 evenly spaced points between 0 and 2 pi
y = np.sin(x)

ax.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 3, 100)
fig, ax = plt.subplots(figsize = (6, 4), layout = 'constrained')
ax.plot(x, x, label = 'Linear')
ax.plot(x, x**2, label = 'Quadratic')
ax.set_xlabel('X value')
ax.set_ylabel('Y value')
ax.set_title('Simple Plot')
ax.legend
plt.show()

# %%
from numpy.random.mtrand import randint
np.random.seed(123)
data = {'a' : np.arrange(50), # 50 integers from 0 to 49
        'c' : np.random.randint(0, 50, 50), # 50 random integers from 0 to 49
        'd' : np.random.randn(50)} # 50 normally dsitributed random values
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

ax.scatter('a', 'b', c = 'c', s = 'd', data = data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-252090366.py in <cell line: 0>()
#       1 from numpy.random.mtrand import randint
#       2 np.random.seed(123)
# ----> 3 data = {'a' : np.arrange(50), # 50 integers from 0 to 49
#       4         'c' : np.random.randint(0, 50, 50), # 50 random integers from 0 to 49
#       5         'd' : np.random.randn(50)} # 50 normally dsitributed random values
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     408             return char.chararray
#     409
# --> 410         raise AttributeError("module {!r} has no attribute "
#     411                              "{!r}".format(__name__, attr))
#     412
#
# AttributeError: module 'numpy' has no attribute 'arrange'
